# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"D:\AI ML\Resorses csv Files/age_experience_salary_dataset.csv")

# %%
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   58          35  164615
# 1   48          30  127422
# 2   34          11   65863

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)

# %%
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["Salary"]

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
dataset.describe()
# Out:
#                Age  Experience         Salary
# count  1000.000000   1000.0000    1000.000000
# mean     39.991000     19.1060  101273.676000
# std      11.780055     11.8305   40311.007186
# min      20.000000      0.0000   27549.000000
# 25%      30.000000      8.0000   65692.750000
# 50%      41.000000     20.0000  104957.000000
# 75%      50.250000     29.0000  136281.750000
# max      59.000000     41.0000  179160.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)*100
# Out:
# 97.98721789136536
