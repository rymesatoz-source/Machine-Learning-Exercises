# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv(r"D:\AI ML\Resorses csv Files\placement.csv")

# %%
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="package", data=dataset)
plt.show()

# %%
x = dataset["cgpa"]
y = dataset["package"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
lr.coef_, lr.intercept_
# Out:
# (array([0.57425647]), np.float64(-1.0270069374542108))

# %%
score = lr.score(x_test.values.reshape(-1, 1), y_test) * 100
print("Accuracy:", score)
# Out:
# Accuracy: 77.30984312051673

# %%
lr.predict([[6.89]])
# Out:
# array([2.92962016])

# %%
0.57425647*6.89-1.0270069374542108
# Out:
# 2.929620140845789

# %%
y_prd = lr.predict(x_test.values.reshape(-1, 1))

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="package", data=dataset)
plt.plot(x_test, lr.predict(x_test.values.reshape(-1, 1)), color='Blue', linewidth=2)
plt.legend(['org data', 'predicted data'])
plt.savefig("predicted.jpg")
plt.show()
