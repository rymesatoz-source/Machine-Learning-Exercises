# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset.head(3)
# Out:
#    Level  Salary
# 0      1   12345
# 1      2    -940
# 2      3    5340

# %%
plt.scatter(dataset["Level"], dataset["Salary"])
plt.show()

# %%
# Data load
dataset = pd.read_csv(r"D:\AI ML\Resorses csv Files\polynomial.csv")
X = dataset[['Level']].values
y = dataset['Salary'].values

# %%
# Polynomial transform
poly = PolynomialFeatures(degree=2)  # degree badha kar curve aur smooth ho jayega
X_poly = poly.fit_transform(X)

# %%
# Polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 95.44667121318757

# %%
# Predictions
y_pred = model.predict(X_poly)

# %%
# Plot
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.legend(['Actual', 'Predicted'])
plt.title("Polynomial Regression")
plt.show()

# %%
lr.coefficients_,intercept
# Out:
# (array([   0.        , 1532.52420935,   49.86769748]),
#  np.float64(3208.5428323408123))
